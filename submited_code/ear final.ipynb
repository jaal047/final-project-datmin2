# %%
import glob
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
def load_img_folder(path):
    lst = []
    for img in glob.glob(path+'*.jpg'):
        n= plt.imread(img)
        lst.append(n)
    return np.array(lst)

# awake_img = np.array(awake_img)

# %%
awake_path = "C:/Users/ACER/OneDrive - Universitas Airlangga/KULIAH/semester 5/bbb data mining/final_project/final-project-datmin2/images/awake/awake"
drowsy_path = "C:/Users/ACER/OneDrive - Universitas Airlangga/KULIAH/semester 5/bbb data mining/final_project/final-project-datmin2/images/drowsy/drowsy"
# awake_path = "/images/awake/awake"
# drowsy_path = "/images/drowsy/drowsy"
awake_img = load_img_folder(awake_path)
drowsy_img = load_img_folder(drowsy_path)

# %%
awake_img.shape
# Out:
# (91, 480, 640, 3)

# %%
drowsy_img.shape
# Out:
# (94, 480, 640, 3)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import mediapipe as mp

mp_facemesh = mp.solutions.face_mesh
mp_drawing  = mp.solutions.drawing_utils
denormalize_coordinates = mp_drawing._normalized_to_pixel_coordinates

# %matplotlib inline

# Landmark points corresponding to left eye
all_left_eye_idxs = list(mp_facemesh.FACEMESH_LEFT_EYE)
# flatten and remove duplicates
all_left_eye_idxs = set(np.ravel(all_left_eye_idxs)) 

# Landmark points corresponding to right eye
all_right_eye_idxs = list(mp_facemesh.FACEMESH_RIGHT_EYE)
all_right_eye_idxs = set(np.ravel(all_right_eye_idxs))

# Combined for plotting - Landmark points for both eye
all_idxs = all_left_eye_idxs.union(all_right_eye_idxs)

# The chosen 12 points:   P1,  P2,  P3,  P4,  P5,  P6
chosen_left_eye_idxs  = [362, 385, 387, 263, 373, 380]
chosen_right_eye_idxs = [33,  160, 158, 133, 153, 144]
all_chosen_idxs = chosen_left_eye_idxs + chosen_right_eye_idxs

# %%
def distance(point_1, point_2):
    """Calculate l2-norm between two points"""
    dist = sum([(i - j) ** 2 for i, j in zip(point_1, point_2)]) ** 0.5
    return dist

def get_ear(landmarks, refer_idxs, frame_width, frame_height):
    """
    Calculate Eye Aspect Ratio for one eye.

    Args:
        landmarks: (list) Detected landmarks list
        refer_idxs: (list) Index positions of the chosen landmarks
                            in order P1, P2, P3, P4, P5, P6
        frame_width: (int) Width of captured frame
        frame_height: (int) Height of captured frame

    Returns:
        ear: (float) Eye aspect ratio
    """
    try:
        # Compute the euclidean distance between the horizontal
        coords_points = []
        for i in refer_idxs:
            lm = landmarks[i]
            coord = denormalize_coordinates(lm.x, lm.y, 
                                             frame_width, frame_height)
            coords_points.append(coord)

        # Eye landmark (x, y)-coordinates
        P2_P6 = distance(coords_points[1], coords_points[5])
        P3_P5 = distance(coords_points[2], coords_points[4])
        P1_P4 = distance(coords_points[0], coords_points[3])

        # Compute the eye aspect ratio
        ear = (P2_P6 + P3_P5) / (2.0 * P1_P4)

    except:
        ear = 0.0
        coords_points = None

    return ear, coords_points

def calculate_avg_ear(landmarks, left_eye_idxs, right_eye_idxs, image_w, image_h):
    """Calculate Eye aspect ratio"""

    left_ear, left_lm_coordinates = get_ear(
                                      landmarks, 
                                      left_eye_idxs, 
                                      image_w, 
                                      image_h
                                    )
    right_ear, right_lm_coordinates = get_ear(
                                      landmarks, 
                                      right_eye_idxs, 
                                      image_w, 
                                      image_h
                                    )
    Avg_EAR = (left_ear + right_ear) / 2.0

    return Avg_EAR, (left_lm_coordinates, right_lm_coordinates)

# %%
def final_ear(img_read, ear_thresh=0.2):
    image = np.ascontiguousarray(img_read)
    imgH, imgW, _ = image.shape
    custom_chosen_lmk_image = image.copy()
    
    with mp_facemesh.FaceMesh(refine_landmarks=True) as face_mesh:
        results = face_mesh.process(image).multi_face_landmarks
        
        if results:
            for face_id, face_landmarks in enumerate(results):
                landmarks = face_landmarks.landmark
                EAR, _ = calculate_avg_ear(
                          landmarks, 
                          chosen_left_eye_idxs, 
                          chosen_right_eye_idxs, 
                          imgW, 
                          imgH
                      )
                if EAR < ear_thresh:
                    return [EAR, 'drowsy']
                elif EAR >= ear_thresh:
                    return [EAR, 'awake']
#                 return EAR

# %%
def goodness_model(awake_array, drowsy_array, ear_thresh=0.2):
    hasil_awake = []
    for i in range(len(awake_array)):
        try:
            ear_result = final_ear(awake_array[i],ear_thresh)[1]
            hasil_awake.append(ear_result)    
        except:
            pass

    hasil_drowsy = []
    for i in range(len(drowsy_array)):
        try:
            ear_result = final_ear(drowsy_array[i],ear_thresh)[1]
            hasil_drowsy.append(ear_result)    
        except:
            pass 
        
    con_matrix = np.array([[hasil_awake.count('awake'), hasil_awake.count('drowsy')],
              [hasil_drowsy.count('awake'), hasil_drowsy.count('drowsy')]])
    
    TP = con_matrix[0][0]
    FN = con_matrix[0][1]
    FP = con_matrix[1][0]
    TN = con_matrix[1][1]

    ear_acc = (TP+TN)/(TP+TN+FN+FP)
    ear_rec = (TP)/(TP+FN)
    ear_pre = (TP)/(TP+FP)
    ear_f1s = (2*TP)/(2*TP+FP+FN)
    
    result = {'acc': ear_acc,
              'rec': ear_rec,
              'pre': ear_pre,
              'f1s': ear_f1s}
    
    return result

# %%
thresh_018 = goodness_model(awake_img, drowsy_img, 0.18)
thresh_019 = goodness_model(awake_img, drowsy_img, 0.19)
thresh_020 = goodness_model(awake_img, drowsy_img, 0.2)
thresh_021 = goodness_model(awake_img, drowsy_img, 0.21)
thresh_022 = goodness_model(awake_img, drowsy_img, 0.22)

# %%
list_metode = ['thresh_018','thresh_019','thresh_020','thresh_021','thresh_022']
list_acc = []
list_rec = []
list_pre = []
list_f1s = []

# %%
list_thresh = [thresh_018,thresh_019,thresh_020,thresh_021,thresh_022]
list_param = ['acc','rec','pre','f1s']

for i in list_thresh:
    for j in i:
        if j=='acc':
            list_acc.append(i[j])
        elif j=='rec':
            list_rec.append(i[j])
        elif j=='pre':
            list_pre.append(i[j])
        elif j=='f1s':
            list_f1s.append(i[j])

# %%
import pandas as pd
import seaborn as sns
summ = pd.DataFrame({"metode":list_metode,
                    'akurasi':list_acc,
                    'recall':list_rec,
                    'precision': list_pre,
                    'f1-score': list_f1s})
summ = summ.sort_values(by=['akurasi'],ascending=False).reset_index(drop=True)
cm = sns.light_palette("blue", as_cmap=True)
summ.style.background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_eb3ec_row0_col1, #T_eb3ec_row1_col1, #T_eb3ec_row1_col3, #T_eb3ec_row2_col2, #T_eb3ec_row2_col4 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# #T_eb3ec_row0_col2 {
#   background-color: #9999f7;
#   color: #f1f1f1;
# }
# #T_eb3ec_row0_col3 {
#   background-color: #5757fb;
#   color: #f1f1f1;
# }
# #T_eb3ec_row0_col4 {
#   background-color: #7c7cf9;
#   color: #f1f1f1;
# }
# #T_eb3ec_row1_col2, #T_eb3ec_row1_col4, #T_eb3ec_row2_col3, #T_eb3ec_row4_col1 {
#   background-color: #f0f0f3;
#   color: #000000;
# }
# #T_eb3ec_row2_col1, #T_eb3ec_row3_col1 {
#   background-color: #5050fb;
#   color: #f1f1f1;
# }
# #T_eb3ec_row3_col2 {
#   background-color: #1616fe;
#   color: #f1f1f1;
# }
# #T_eb3ec_row3_col3 {
#   background-color: #e1e1f4;
#   color: #000000;
# }
# #T_eb3ec_row3_col4 {
#   background-color: #1919fe;
#   color: #f1f1f1;
# }
# #T_eb3ec_row4_col2 {
#   background-color: #5858fb;
#   color: #f1f1f1;
# }
# #T_eb3ec_row4_col3 {
#   background-color: #e8e8f3;
#   color: #000000;
# }
# #T_eb3ec_row4_col4 {
#   background-color: #dcdcf4;
#   color: #000000;
# }
# </style>
# <table id="T_eb3ec">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eb3ec_level0_col0" class="col_heading level0 col0" >metode</th>
#       <th id="T_eb3ec_level0_col1" class="col_heading level0 col1" >akurasi</th>
#       <th id="T_eb3ec_level0_col2" class="col_heading level0 col2" >recall</th>
#       <th id="T_eb3ec_level0_col3" class="col_heading level0 col3" >precision</th>
#       <th id="T_eb3ec_level0_col4" class="col_heading level0 col4" >f1-score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eb3ec_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_eb3ec_row0_col0" class="data row0 col0" >thresh_021</td>
#       <td id="T_eb3ec_row0_col1" class="data row0 col1" >0.793478</td>
#       <td id="T_eb3ec_row0_col2" class="data row0 col2" >0.912088</td>
#       <td id="T_eb3ec_row0_col3" class="data row0 col3" >0.734513</td>
#       <td id="T_eb3ec_row0_col4" class="data row0 col4" >0.813725</td>
#     </tr>
#     <tr>
#       <th id="T_eb3ec_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_eb3ec_row1_col0" class="data row1 col0" >thresh_022</td>
#       <td id="T_eb3ec_row1_col1" class="data row1 col1" >0.793478</td>
#       <td id="T_eb3ec_row1_col2" class="data row1 col2" >0.868132</td>
#       <td id="T_eb3ec_row1_col3" class="data row1 col3" >0.752381</td>
#       <td id="T_eb3ec_row1_col4" class="data row1 col4" >0.806122</td>
#     </tr>
#     <tr>
#       <th id="T_eb3ec_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_eb3ec_row2_col0" class="data row2 col0" >thresh_018</td>
#       <td id="T_eb3ec_row2_col1" class="data row2 col1" >0.788043</td>
#       <td id="T_eb3ec_row2_col2" class="data row2 col2" >0.989011</td>
#       <td id="T_eb3ec_row2_col3" class="data row2 col3" >0.703125</td>
#       <td id="T_eb3ec_row2_col4" class="data row2 col4" >0.821918</td>
#     </tr>
#     <tr>
#       <th id="T_eb3ec_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_eb3ec_row3_col0" class="data row3 col0" >thresh_019</td>
#       <td id="T_eb3ec_row3_col1" class="data row3 col1" >0.788043</td>
#       <td id="T_eb3ec_row3_col2" class="data row3 col2" >0.978022</td>
#       <td id="T_eb3ec_row3_col3" class="data row3 col3" >0.706349</td>
#       <td id="T_eb3ec_row3_col4" class="data row3 col4" >0.820276</td>
#     </tr>
#     <tr>
#       <th id="T_eb3ec_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_eb3ec_row4_col0" class="data row4 col0" >thresh_020</td>
#       <td id="T_eb3ec_row4_col1" class="data row4 col1" >0.777174</td>
#       <td id="T_eb3ec_row4_col2" class="data row4 col2" >0.945055</td>
#       <td id="T_eb3ec_row4_col3" class="data row4 col3" >0.704918</td>
#       <td id="T_eb3ec_row4_col4" class="data row4 col4" >0.807512</td>
#     </tr>
#   </tbody>
# </table>
