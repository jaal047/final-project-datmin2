# %%
# from skimage.io import imread_collection

# #your path 
# col_dir = 'capture/ur_capture/awake/*.jpg'

# #creating a collection with the available images
# col = imread_collection(col_dir)

# %%
import glob
awake_img = []
for img in glob.glob("capture/ur_capture/awake/*.jpg"):
    n= cv2.imread(img)
    awake_img.append(n)

# %%
def remove_bg(file):
    from rembg import remove
    output = remove(file)
    return output

# %%
# import matplotlib.pyplot as plt
# print(plt.imshow(remove_bg(col[0])))
# # cv2.imshow()

# %%
awake_img
# Out:
# [array([[[157, 159, 159],
#          [156, 158, 158],
#          [155, 157, 157],
#          ...,
#          [251, 251, 251],
#          [251, 251, 251],
#          [251, 251, 251]],
#
#         [[156, 158, 158],
#          [156, 158, 158],
#          [156, 158, 158],
#          ...,
#          [251, 251, 251],
#          [251, 251, 251],
#          [251, 251, 251]],
#
#         [[156, 161, 159],
#          [156, 161, 159],
#          [156, 161, 160],
#          ...,
#          [251, 251, 251],
#          [251, 251, 251],
#          [251, 251, 251]],
#
#         ...,
#
#         [[155, 154, 150],
#          [155, 154, 150],
#          [153, 153, 147],
#          ...,
#          [ 81,  91, 108],
#          [ 83,  92, 112],
#          [ 83,  91, 114]],
#
#         [[155, 154, 150],
#          [155, 154, 150],
#          [152, 152, 146],
#          ...,
#          [ 83,  93, 110],
#          [ 78,  87, 107],
#          [ 80,  88, 111]],
#
#         [[155, 154, 150],
#          [155, 154, 150],
#          [152, 152, 146],
#          ...,
#          [ 84,  94, 111],
#          [ 75,  84, 104],
#          [ 82,  90, 113]]], dtype=uint8),
#  array([[[155, 155, 155],
#          [158, 158, 158],
#          [160, 160, 160],
#          ...,
#          [251, 251, 251],
#          [251, 252, 250],
#          [251, 252, 250]],
#
#         [[159, 159, 159],
#          [160, 160, 160],
#          [160, 160, 160],
#          ...,
#          [251, 251, 251],
#          [251, 252, 250],
#          [251, 252, 250]],
#
#         [[158, 160, 160],
#          [159, 161, 161],
#          [158, 160, 160],
#          ...,
#          [251, 251, 251],
#          [251, 251, 251],
#          [251, 251, 251]],
#
#         ...,
#
#         [[156, 154, 143],
#          [157, 155, 144],
#          [160, 157, 143],
#          ...,
#          [ 79,  92, 106],
#          [ 77,  87, 104],
#          [ 74,  84, 101]],
#
#         [[156, 155, 141],
#          [156, 155, 141],
#          [157, 156, 142],
#          ...,
#          [ 79,  90, 104],
#          [ 78,  88, 105],
#          [ 77,  87, 105]],
#
#         [[154, 153, 139],
#          [155, 154, 140],
#          [157, 156, 142],
#          ...,
#          [ 79,  90, 104],
#          [ 82,  92, 110],
#          [ 84,  94, 112]]], dtype=uint8),
#  array([[[154, 154, 154],
#          [154, 154, 154],
#          [154, 154, 154],
#          ...,
#          [251, 250, 252],
#          [249, 251, 251],
#          [248, 250, 250]],
#
#         [[156, 156, 156],
#          [156, 156, 156],
#          [156, 156, 156],
#          ...,
#          [251, 250, 252],
#          [250, 252, 252],
#          [249, 251, 251]],
#
#         [[157, 157, 157],
#          [157, 157, 157],
#          [156, 156, 156],
#          ...,
#          [251, 251, 251],
#          [252, 252, 252],
#          [252, 252, 252]],
#
#         ...,
#
#         [[146, 148, 136],
#          [148, 150, 138],
#          [152, 152, 140],
#          ...,
#          [ 78,  87, 101],
#          [ 80,  89, 103],
#          [ 82,  91, 105]],
#
#         [[147, 149, 137],
#          [146, 148, 136],
#          [149, 149, 137],
#          ...,
#          [ 78,  87, 100],
#          [ 75,  87,  99],
#          [ 78,  90, 102]],
#
#         [[151, 153, 141],
#          [147, 149, 137],
#          [147, 147, 135],
#          ...,
#          [ 78,  87, 100],
#          [ 75,  87,  99],
#          [ 78,  90, 102]]], dtype=uint8),
#  array([[[159, 159, 159],
#          [160, 160, 160],
#          [161, 161, 161],
#          ...,
#          [251, 251, 251],
#          [251, 251, 251],
#          [252, 252, 252]],
#
#         [[158, 158, 158],
#          [160, 160, 160],
#          [161, 161, 161],
#          ...,
#          [251, 251, 251],
#          [251, 251, 251],
#          [252, 252, 252]],
#
#         [[159, 159, 159],
#          [160, 160, 160],
#          [160, 160, 160],
#          ...,
#          [251, 251, 251],
#          [251, 251, 251],
#          [251, 251, 251]],
#
#         ...,
#
#         [[155, 152, 147],
#          [156, 154, 146],
#          [157, 154, 146],
#          ...,
#          [ 81,  88, 105],
#          [ 84,  89, 110],
#          [ 83,  88, 109]],
#
#         [[155, 153, 145],
#          [156, 154, 146],
#          [158, 155, 147],
#          ...,
#          [ 80,  87, 104],
#          [ 81,  86, 107],
#          [ 83,  88, 109]],
#
#         [[159, 157, 149],
#          [159, 157, 149],
#          [160, 158, 148],
#          ...,
#          [ 84,  91, 108],
#          [ 82,  87, 108],
#          [ 83,  88, 109]]], dtype=uint8),
#  array([[[128, 128, 128],
#          [127, 127, 127],
#          [123, 125, 125],
#          ...,
#          [214, 223, 237],
#          [219, 228, 241],
#          [221, 230, 243]],
#
#         [[133, 133, 133],
#          [132, 132, 132],
#          [128, 130, 130],
#          ...,
#          [226, 235, 248],
#          [232, 242, 252],
#          [235, 245, 255]],
#
#         [[132, 132, 132],
#          [131, 131, 131],
#          [129, 129, 129],
#          ...,
#          [239, 248, 255],
#          [242, 252, 255],
#          [243, 253, 255]],
#
#         ...,
#
#         [[135, 134, 120],
#          [134, 133, 119],
#          [139, 136, 122],
#          ...,
#          [ 67,  76,  90],
#          [ 68,  76,  93],
#          [ 70,  78,  95]],
#
#         [[133, 132, 118],
#          [133, 132, 118],
#          [137, 136, 122],
#          ...,
#          [ 70,  79,  93],
#          [ 68,  76,  93],
#          [ 69,  77,  94]],
#
#         [[138, 137, 123],
#          [137, 136, 122],
#          [138, 137, 123],
#          ...,
#          [ 71,  80,  94],
#          [ 69,  77,  94],
#          [ 69,  77,  94]]], dtype=uint8),
#  array([[[157, 157, 157],
#          [157, 157, 157],
#          [157, 157, 157],
#          ...,
#          [251, 251, 251],
#          [251, 251, 251],
#          [251, 251, 251]],
#
#         [[158, 158, 158],
#          [157, 157, 157],
#          [157, 157, 157],
#          ...,
#          [251, 251, 251],
#          [251, 251, 251],
#          [251, 251, 251]],
#
#         [[158, 158, 158],
#          [158, 158, 158],
#          [158, 158, 158],
#          ...,
#          [251, 251, 251],
#          [251, 251, 251],
#          [251, 251, 251]],
#
#         ...,
#
#         [[155, 153, 142],
#          [154, 152, 141],
#          [154, 152, 141],
#          ...,
#          [ 52,  50,  49],
#          [ 56,  55,  51],
#          [ 59,  58,  54]],
#
#         [[157, 153, 142],
#          [157, 153, 142],
#          [157, 153, 142],
#          ...,
#          [ 55,  53,  52],
#          [ 59,  58,  54],
#          [ 60,  59,  55]],
#
#         [[157, 153, 142],
#          [157, 153, 142],
#          [156, 152, 141],
#          ...,
#          [ 57,  55,  54],
#          [ 61,  60,  56],
#          [ 61,  60,  56]]], dtype=uint8),
#  array([[[151, 158, 155],
#          [150, 157, 154],
#          [150, 155, 153],
#          ...,
#          [251, 251, 251],
#          [251, 251, 251],
#          [251, 251, 251]],
#
#         [[150, 157, 154],
#          [150, 157, 154],
#          [151, 156, 154],
#          ...,
#          [251, 251, 251],
#          [252, 252, 252],
#          [251, 251, 251]],
#
#         [[150, 157, 154],
#          [151, 158, 155],
#          [152, 157, 155],
#          ...,
#          [251, 251, 251],
#          [252, 252, 252],
#          [251, 251, 251]],
#
#         ...,
#
#         [[148, 149, 140],
#          [149, 150, 141],
#          [151, 149, 141],
#          ...,
#          [ 67,  80,  94],
#          [ 68,  81,  97],
#          [ 73,  86, 102]],
#
#         [[151, 152, 142],
#          [150, 151, 141],
#          [151, 150, 140],
#          ...,
#          [ 68,  81,  95],
#          [ 67,  80,  96],
#          [ 70,  83,  99]],
#
#         [[152, 153, 143],
#          [149, 150, 140],
#          [150, 149, 139],
#          ...,
#          [ 67,  80,  94],
#          [ 63,  76,  92],
#          [ 63,  76,  92]]], dtype=uint8),
#  array([[[131, 136, 135],
#          [130, 135, 134],
#          [132, 134, 134],
#          ...,
#          [250, 252, 253],
#          [251, 253, 253],
#          [251, 253, 253]],
#
#         [[131, 136, 135],
#          [131, 136, 135],
#          [134, 136, 136],
#          ...,
#          [250, 252, 253],
#          [251, 253, 253],
#          [251, 253, 253]],
#
#         [[133, 138, 137],
#          [132, 137, 136],
#          [135, 137, 137],
#          ...,
#          [251, 253, 253],
#          [254, 254, 254],
#          [254, 254, 254]],
#
#         ...,
#
#         [[142, 139, 124],
#          [138, 135, 120],
#          [139, 134, 119],
#          ...,
#          [ 69,  78,  92],
#          [ 69,  78,  92],
#          [ 69,  78,  92]],
#
#         [[143, 141, 123],
#          [140, 138, 120],
#          [141, 137, 119],
#          ...,
#          [ 69,  77,  94],
#          [ 70,  77,  94],
#          [ 71,  78,  95]],
#
#         [[146, 144, 126],
#          [144, 142, 124],
#          [146, 142, 124],
#          ...,
#          [ 69,  77,  94],
#          [ 69,  76,  93],
#          [ 70,  77,  94]]], dtype=uint8),
#  array([[[180, 179, 181],
#          [181, 180, 182],
#          [183, 182, 184],
#          ...,
#          [251, 251, 251],
#          [251, 251, 251],
#          [251, 251, 251]],
#
#         [[184, 183, 185],
#          [181, 180, 182],
#          [180, 179, 181],
#          ...,
#          [251, 251, 251],
#          [251, 251, 251],
#          [251, 251, 251]],
#
#         [[181, 183, 184],
#          [181, 183, 184],
#          [181, 183, 184],
#          ...,
#          [251, 251, 251],
#          [251, 251, 251],
#          [251, 251, 251]],
#
#         ...,
#
#         [[174, 172, 161],
#          [174, 172, 161],
#          [175, 173, 162],
#          ...,
#          [ 93, 106, 122],
#          [ 92, 106, 124],
#          [ 88, 102, 120]],
#
#         [[174, 172, 162],
#          [174, 172, 161],
#          [174, 172, 161],
#          ...,
#          [ 90, 105, 121],
#          [ 92, 107, 123],
#          [ 88, 103, 119]],
#
#         [[175, 173, 163],
#          [175, 173, 163],
#          [174, 172, 161],
#          ...,
#          [ 88, 103, 119],
#          [ 92, 107, 123],
#          [ 90, 105, 121]]], dtype=uint8),
#  array([[[115, 123, 122],
#          [113, 121, 120],
#          [112, 120, 119],
#          ...,
#          [218, 232, 244],
#          [219, 233, 245],
#          [221, 236, 245]],
#
#         [[115, 123, 122],
#          [114, 122, 121],
#          [114, 122, 121],
#          ...,
#          [229, 243, 255],
#          [230, 245, 254],
#          [231, 247, 254]],
#
#         [[114, 122, 121],
#          [115, 123, 122],
#          [115, 123, 122],
#          ...,
#          [238, 251, 255],
#          [238, 252, 255],
#          [239, 253, 255]],
#
#         ...,
#
#         [[125, 122, 107],
#          [123, 120, 105],
#          [122, 117, 102],
#          ...,
#          [ 55,  64,  78],
#          [ 56,  65,  79],
#          [ 54,  63,  77]],
#
#         [[125, 120, 105],
#          [125, 120, 105],
#          [124, 119, 104],
#          ...,
#          [ 57,  66,  80],
#          [ 58,  67,  80],
#          [ 55,  64,  77]],
#
#         [[123, 118, 103],
#          [124, 119, 104],
#          [126, 121, 106],
#          ...,
#          [ 56,  65,  79],
#          [ 56,  65,  78],
#          [ 53,  62,  75]]], dtype=uint8)]
