# %%
import glob
import cv2
import numpy as np
awake_img = []

for img in glob.glob("capture/ur_capture/awake/*.jpg"):
    n= plt.imread(img)
    awake_img.append(n)

awake_img = np.array(awake_img)

# %%
def remove_bg(file):
    from rembg import remove
    output = remove(file)
    return output

# %%
import matplotlib.pyplot as plt
plt.imshow(awake_img[0])

# %%
len(awake_img)
# Out:
# 10

# %%
awake_img_rembg = []
for i in range(len(awake_img)):
    awake_img_rembg.append(remove_bg(awake_img[i]))

# %%
plt.imshow(awake_img_rembg[2])
